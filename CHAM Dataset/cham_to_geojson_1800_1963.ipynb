# %%
# import pandas as pd
# import requests

# def geocode_city_state(city_state):
#     url = f"https://nominatim.openstreetmap.org/search?format=json&q={city_state}"
#     response = requests.get(url)
#     if response.status_code == 200:
#         data = response.json()
#         if data:
#             return data[0]['lat'], data[0]['lon']
#     return None, None

# # Read the original CSV file
# original_csv_file = 'cleaned_cham_api_1800_1963.csv'
# data = pd.read_csv(original_csv_file)

# # Function to extract latitude and longitude from place
# def extract_coordinates(row):
#     place = row['City']
#     longitude, latitude = geocode_city_state(place)
#     return longitude, latitude

# # Apply the function to the DataFrame
# data['reclong'], data['reclat'] = zip(*data.apply(extract_coordinates, axis=1))

# # Save the new CSV file
# new_csv_file = 'cham_geo_dataset_1800.csv'
# data.to_csv(new_csv_file, index=False)

# print("New CSV file has been created with latitude and longitude columns.")

# %%
# import pandas as pd
# import json

# def csv_to_geojson(csv_file):
#     data = pd.read_csv(csv_file)
    
#     features = []
#     for _, row in data.iterrows():
#         # Check if location coordinates are not NaN
#         if not pd.isna(row['reclong']) and not pd.isna(row['reclat']):
#             feature = {
#                 'type': 'Feature',
#                 'properties': {
#                     'date': row['date'],
#                     'title': row['title'],
#                     'id': row['id'],
#                     'place': row['place'],
#                 },
#                 'geometry': {
#                     'type': 'Point',
#                     'coordinates': [row['reclong'], row['reclat']]
#                 }
#             }
#             features.append(feature)
    
#     geojson_data = {
#         'type': 'FeatureCollection',
#         'features': features
#     }
    
#     return json.dumps(geojson_data)

# # Example usage:
# csv_file = 'cham_geo_dataset_1800.csv'
# geojson = csv_to_geojson(csv_file)

# # Save the GeoJSON to a file
# output_geojson_file = 'cham_1800_1963.geojson'
# with open(output_geojson_file, 'w') as f:
#     f.write(geojson)

# print("success")

# %%
import pandas as pd
import requests
import json
import time

def geocode_city_state(city_state, max_retries=3):
    # List of known problematic inputs to skip processing
    skip_list = ['City1, State1', 'City2, State2', 'City3, State3']
    
    if city_state in skip_list:
        print("Skipping processing for:", city_state)
        return None, None
    
    retries = 0
    while retries < max_retries:
        try:
            print("Geocoding:", city_state)
            url = f"https://nominatim.openstreetmap.org/search?format=json&q={city_state}"
            response = requests.get(url)
            if response.status_code == 200:
                data = response.json()
                if data:
                    return data[0]['lat'], data[0]['lon']
        except Exception as e:
            print("Error:", e)
        
        # Increment retry count and wait before retrying
        retries += 1
        if retries < max_retries:
            print("Retrying after 3 seconds...")
            time.sleep(3)
    
    # Return None if all retries failed
    return None, None

# Read the original CSV file
original_csv_file = 'cleaned_cham_api_1800_1963.csv'
data = pd.read_csv(original_csv_file)

# Updated function to extract latitude and longitude from place
def extract_coordinates(row):
    if pd.isna(row['City']) or pd.isna(row['State']):
        return None, None
    
    city_state = row['City'] + ', ' + row['State']
    latitude, longitude = geocode_city_state(city_state)
    return latitude, longitude

# Add timestamps to track execution time
start_time = time.time()

# Apply the function to the DataFrame
data['reclat'], data['reclong'] = zip(*data.apply(extract_coordinates, axis=1))

# Check for NaN values
print("NaN values after geocoding:", data[['reclat', 'reclong']].isnull().sum())

# Drop rows with NaN values
data.dropna(subset=['reclat', 'reclong'], inplace=True)

# Save the new CSV file
new_csv_file = 'cham_geo_dataset_1800.csv'
data.to_csv(new_csv_file, index=False)
print("CSV file saved successfully.")

# Print execution time
end_time = time.time()
execution_time = end_time - start_time
print("Data processing completed in", execution_time, "seconds.")

def csv_to_geojson(csv_file):
    data = pd.read_csv(csv_file)
    
    features = []
    for _, row in data.iterrows():
        feature = {
            'type': 'Feature',
            'properties': {
                'date': row['date'],
                'title': row['title'],
                'id': row['id'],
                'place': row['place']
            },
            'geometry': {
                'type': 'Point',
                'coordinates': [row['reclong'], row['reclat']]
            }
        }
        features.append(feature)
    
    geojson_data = {
        'type': 'FeatureCollection',
        'features': features
    }
    
    return json.dumps(geojson_data)

# Example usage:
csv_file = 'cham_geo_dataset_1800.csv'
geojson = csv_to_geojson(csv_file)

# Save the GeoJSON to a file
output_geojson_file = 'cham_1800_1963.geojson'
with open(output_geojson_file, 'w') as f:
    f.write(geojson)

print("GeoJSON file has been created successfully.")
# Out:
# Geocoding: Omaha, Neb.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Salt Lake City, Utah
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Great Falls, Mont.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Worcester, Mass.
# Geocoding: Richmond, Va.
# Geocoding: Washington, D.C.
# Geocoding: Honolulu, Oahu
# Geocoding: Montgomery, Ala.
# Geocoding: New York, N.Y.
# Geocoding: Birmingham, Ala.
# Geocoding: Detroit, Mich
# Geocoding: Red Lodge, Mont.
# Geocoding: Cordele, Georgia
# Geocoding: New York, N.Y.
# Geocoding: Washington, D.C.
# Geocoding: Minneapolis, Minn.
# Geocoding: Sauk Centre, Stearns County
# Geocoding: Jackson, Miss.
# Geocoding: Detroit, Mich
# Geocoding: New York, N.Y.
# Geocoding: Seattle, Wash. Terr. [Wash.
# Geocoding: Rock Island, Ill.
# Geocoding: Las Vegas, Nev.
# Geocoding: Nome, Alaska
# Geocoding: Monroe City, Mo.
# Geocoding: Seward, Alaska
# Geocoding: Marietta, Ohio
# Geocoding: Topeka, Kansas
# Geocoding: Washington, D.C.
# Geocoding: Tulsa, Okla.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Ely, Minn.
# Geocoding: Wheeling, W. Va.
# Geocoding: New Britain, Conn.
# Geocoding: Dillon, S.C.
# Geocoding: Keokuk, Iowa
# Geocoding: Libby, Mont.
# Geocoding: Washington, D.C.
# Geocoding: Chapel Hill, N.C.
# Geocoding: Passaic City, N.J.
# Geocoding: Washington, D.C.
# Geocoding: Grand Forks, N.D.
# Geocoding: Louisville, Ky.
# Geocoding: New York, N.Y.
# Geocoding: Tonopah, Nev.
# Geocoding: Mineral Point, Wis.
# Geocoding: Key West, Fla.
# Geocoding: Key West, Fla.
# Geocoding: Nome, Alaska
# Geocoding: Waterbury, Conn.
# Geocoding: San Antonio, Tex.
# Geocoding: Browning, Mont.
# Geocoding: Washington, D.C.
# Geocoding: Detroit, Mich
# Geocoding: Parma, Idaho
# Geocoding: Detroit, Mich
# Geocoding: New York, N.Y.
# Geocoding: Hahnville, La.
# Geocoding: Sylva, N.C.
# Geocoding: Honolulu, Hawaiian Islands
# Geocoding: O'Neill City, Holt County
# Retrying after 3 seconds...
# Geocoding: O'Neill City, Holt County
# Retrying after 3 seconds...
# Geocoding: O'Neill City, Holt County
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Brownsville, Tex.
# Geocoding: New York, N.Y.
# Geocoding: Coolidge, Ariz.
# Geocoding: Washington, D.C.
# Geocoding: Bismarck, Dakota [N.D.
# Geocoding: Roy, Mora Co.
# Retrying after 3 seconds...
# Geocoding: Roy, Mora Co.
# Retrying after 3 seconds...
# Geocoding: Roy, Mora Co.
# Geocoding: Roy, Mora Co.
# Retrying after 3 seconds...
# Geocoding: Roy, Mora Co.
# Retrying after 3 seconds...
# Geocoding: Roy, Mora Co.
# Geocoding: Cairo, Ill.
# Geocoding: Bridgeport, Conn.
# Geocoding: Indianapolis, Ind.
# Geocoding: Seward, Alaska
# Geocoding: New York, N.Y.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Holbrook, Navajo County [Ariz.
# Geocoding: Chicago, Ill.
# Geocoding: Honolulu, Oahu
# Geocoding: Minneapolis, Minn.
# Geocoding: Washington, D.C.
# Geocoding: San Antonio, Tex.
# Geocoding: Great Falls, Mont.
# Geocoding: San Antonio, Tex.
# Geocoding: Yorkville, S.C.
# Geocoding: Washington, D.C.
# Geocoding: Honolulu, Oahu
# Geocoding: Silver City, Idaho
# Geocoding: Madison, S.D.
# Geocoding: Harlem, Mont.
# Geocoding: West Randolph, Vt.
# Retrying after 3 seconds...
# Geocoding: West Randolph, Vt.
# Retrying after 3 seconds...
# Geocoding: West Randolph, Vt.
# Geocoding: Salt Lake City, Utah
# Geocoding: Seattle, Wash. Terr. [Wash.
# Geocoding: Phillipsburg, Kan.
# Geocoding: Washington, D.C.
# Geocoding: Camden, Tenn.
# Geocoding: El Centro, Calif.
# Geocoding: Birmingham, Ala.
# Geocoding: Pendleton, OR
# Geocoding: Bisbee, Ariz.
# Geocoding: Pendleton, OR
# Geocoding: Newark, Ark.
# Geocoding: Washington, D.C.
# Geocoding: Passaic City, N.J.
# Geocoding: San Antonio, Tex.
# Geocoding: Batesville, Ark.
# Geocoding: Washington, D.C.
# Geocoding: Omaha, Neb.
# Geocoding: Tacoma, Wash.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Chardon, Geauga County
# Geocoding: Nome, Alaska
# Geocoding: Judsonia, Ark.
# Geocoding: Washington, D.C.
# Geocoding: Arvada, Colo.
# Geocoding: Newberry, S.C.
# Geocoding: Ogden City, Utah
# Geocoding: Chicago, Ill.
# Geocoding: New York, N.Y.
# Geocoding: Indianapolis, Ind.
# Geocoding: Richmond, Va.
# Geocoding: Wallace, Idaho
# Geocoding: Washington, D.C.
# Geocoding: Ordway, Colo.
# Geocoding: Flagstaff, Ariz.
# Geocoding: Flagstaff, Ariz.
# Geocoding: Flagstaff, Ariz.
# Geocoding: Butler, Pa.
# Geocoding: Chicago, Ill.
# Geocoding: Grand Forks, N.D.
# Geocoding: San Francisco, Calif.
# Geocoding: Valdez, Alaska
# Geocoding: Winslow, Ariz.
# Geocoding: Pascagoula, Miss.
# Geocoding: Wichita, Kan.
# Geocoding: Detroit, Mich
# Geocoding: Minneapolis, Minn.
# Geocoding: Charlotte Amalie, St. Thomas
# Geocoding: Indianapolis, Ind.
# Geocoding: Towanda, Pa.
# Geocoding: Montgomery, Ala.
# Geocoding: Eureka, Nev.
# Geocoding: Nebraska City, Neb.
# Geocoding: Nome, Alaska
# Geocoding: El Paso, Tex.
# Geocoding: Cañon City, Colo.
# Geocoding: Martinsburg, W. Va.
# Geocoding: Medicine Lodge, Kan.
# Geocoding: Scranton, Pa.
# Geocoding: New Haven, Conn.
# Geocoding: Cresco, Howard County
# Geocoding: Arizola, Ariz.
# Geocoding: Medina, Ohio
# Geocoding: Washington, D.C.
# Geocoding: Winslow, Ariz.
# Geocoding: Wheeling, W. Va.
# Geocoding: Las Vegas, Nev.
# Geocoding: Shoshone, Idaho
# Geocoding: Indianapolis, Ind.
# Geocoding: Birmingham, Ala.
# Geocoding: Brownsville, Tex.
# Geocoding: Brownsville, Tex.
# Geocoding: Seward, Alaska
# Geocoding: Washington, D.C.
# Geocoding: Detroit, Mich
# Geocoding: Washington, D.C.
# Geocoding: Grand Forks, N.D.
# Geocoding: McMinnville, Tenn.
# Geocoding: Washington, D.C.
# Geocoding: Coolidge, Ariz.
# Geocoding: Milford, Del.
# Geocoding: Florence, Colo.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Iola, Allen County
# Geocoding: Indianapolis, Ind.
# Geocoding: Bamberg, S.C.
# Geocoding: Boulder, Colo.
# Geocoding: Milwaukee, Wis.
# Geocoding: Madison, Fla.
# Geocoding: Roundup, Mont.
# Geocoding: Opelousas, La.
# Geocoding: Abbeville, S.C.
# Geocoding: River Falls, Pierce County
# Geocoding: Port Gibson, Miss.
# Geocoding: Perrysburg, Wood Co.
# Geocoding: Corinth, Miss.
# Geocoding: Oakland, Md.
# Geocoding: St. Johnsbury, Vt.
# Geocoding: Marion, Ky.
# Geocoding: Anaconda, Mont.
# Geocoding: Elbert, Elbert County
# Geocoding: Wheeling, W. Va.
# Geocoding: Hot Springs, S.D.
# Geocoding: Spokane, Wash.
# Geocoding: New York, N.Y.
# Geocoding: Albuquerque, N.M.
# Geocoding: New Britain, Conn.
# Geocoding: Newark, N.J.
# Geocoding: Pawtucket, R.I.
# Geocoding: Poplar, Mont.
# Geocoding: Rising Sun, Md.
# Geocoding: South Bend, Ind.
# Geocoding: Washington, D.C.
# Geocoding: Detroit, Mich
# Geocoding: Lincoln, Neb.
# Geocoding: Lincoln, Neb.
# Geocoding: Yerington, Nev.
# Geocoding: Salt Lake City, Utah
# Geocoding: Bridgeport, Conn.
# Geocoding: Bemidji, Minn.
# Geocoding: Los Angeles, Calif.
# Geocoding: Honolulu, Hawaiian Islands
# Geocoding: Ocala, Fla.
# Geocoding: Ocala, Fla.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Pocomoke City, Md.
# Geocoding: Winslow, Ariz.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: New Britain, Conn.
# Geocoding: Prescott, Ark.
# Geocoding: Baraboo, Wis.
# Geocoding: Nezperce, Idaho
# Geocoding: Lamar, Colo.
# Geocoding: Wadsworth, Nev.
# Geocoding: Audubon, Iowa
# Geocoding: Nome, Alaska
# Geocoding: Pine Bluff, Ark.
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Geocoding: Seward, Alaska
# Geocoding: Laramie, Wyo.
# Geocoding: Pocahontas, Randolph County
# Geocoding: Pierre, S.D.
# Geocoding: Princeton, Minn.
# Geocoding: Pierre, S.D.
# Geocoding: Holbrook, Navajo County [Ariz.
# Geocoding: San Antonio, Tex.
# Geocoding: Keota, Weld County
# Geocoding: Laurel, Mont.
# Geocoding: Smyrna, Del.
# Geocoding: Tulsa, Okla.
# Geocoding: Montgomery, Ala.
# Geocoding: Washington, D.C.
# Geocoding: Tombstone, Ariz.
# Geocoding: Holbrook, Navajo County [Ariz.
# Geocoding: Holbrook, Navajo County [Ariz.
# Geocoding: Lakeland, Fla.
# Geocoding: Lancaster, S.C.
# Geocoding: The Dalles, Or.
# Geocoding: Washington, D.C.
# Geocoding: Cordele, Georgia
# Geocoding: Howard, R.I.
# Geocoding: San Antonio, Tex.
# Geocoding: Holbrook, Ariz.
# Geocoding: Liberty, Miss.
# Geocoding: Valentine, Neb.
# Geocoding: Grand Forks, N.D.
# Geocoding: Kinsley, Kan.
# Geocoding: Baxter Springs, Kan.
# Geocoding: WaKeeney, Kan.
# Geocoding: Honolulu, Hawaiian Islands
# Geocoding: Paducah, Ky.
# Geocoding: Lexington, South Carolina
# Geocoding: Corvallis, Or.
# Geocoding: Salem, Oregon
# Geocoding: Holbrook, Ariz.
# Geocoding: Harrisburg, Pa.
# Geocoding: Mineral Point, Wis.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Parker, Ariz.
# Geocoding: Winslow, Ariz.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Ashdown, Little River County
# Geocoding: Washington, D.C.
# Geocoding: Red Lodge, Mont.
# Geocoding: Battle Mountain, Nev.
# Geocoding: Bluffton, Ohio
# Geocoding: O'Neill City, Holt County
# Retrying after 3 seconds...
# Geocoding: O'Neill City, Holt County
# Retrying after 3 seconds...
# Geocoding: O'Neill City, Holt County
# Geocoding: Nome, Alaska
# Geocoding: Americus, Ga.
# Geocoding: El Centro, Calif.
# Geocoding: Waterbury, Conn.
# Geocoding: Waterbury, Conn.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Juneau, Alaska
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Geocoding: San Antonio, Tex.
# Geocoding: Ventnor City, N.J.
# Geocoding: Tombstone, Ariz.
# Geocoding: Indianapolis, Ind.
# Geocoding: Pascagoula, Miss.
# Geocoding: Augusta, Me.
# Geocoding: St. Paul, Minn.
# Geocoding: Wenatchee, Wash.
# Geocoding: Stillwater, Minn.
# Geocoding: Seattle, Wash.
# Geocoding: Minneapolis, Minn.
# Geocoding: St. Paul, Minn.
# Geocoding: San Francisco, Calif.
# Geocoding: Hopkinsville, Ky.
# Geocoding: Bryan, Tex.
# Geocoding: Crossville, Tenn.
# Geocoding: Crossville, Tenn.
# Geocoding: Alexandria, D.C.
# Geocoding: Montpelier, Idaho
# Geocoding: Wibaux, Mont.
# Geocoding: Elko, Nev.
# Geocoding: Washington, D.C.
# Geocoding: Nome, Alaska
# Geocoding: Nome, Alaska
# Geocoding: Nome, Alaska
# Geocoding: Nome, Alaska
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Geocoding: Nome, Alaska
# Geocoding: Lambertville, N.J.
# Geocoding: Browning, Mont.
# Geocoding: Washington, D.C.
# Geocoding: Fort Benton, Mont.
# Geocoding: McCook, Neb.
# Geocoding: San Antonio, Tex.
# Geocoding: Omaha, Neb.
# Geocoding: Topeka, Kansas
# Geocoding: New Haven, Conn.
# Geocoding: Washington, D.C.
# Geocoding: Honolulu, Oahu
# Geocoding: Phoenix, Ariz.
# Geocoding: Omaha, Neb.
# Geocoding: Providence, R.I.
# Geocoding: Bottineau, Bottineau County
# Geocoding: Marietta, Ohio
# Geocoding: Condon, Gilliam Co.
# Geocoding: Phoenix, Ariz.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Indianapolis, Ind.
# Geocoding: Birmingham, Ala.
# Geocoding: Passaic City, N.J.
# Geocoding: Batesville, Independence Co.
# Geocoding: Plymouth, Ind.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Cheyenne, Wyo.
# Geocoding: Indianapolis, Ind.
# Geocoding: Portland, Me.
# Geocoding: Wichita, Kan.
# Geocoding: Clifton, Dakota [S.D.
# Geocoding: New York, N.Y.
# Geocoding: New York, N.Y.
# Geocoding: Lawrenceburg, Tenn.
# Geocoding: Ceredo, W. Va.
# Geocoding: Providence, R.I.
# Geocoding: St. Paul, Minn.
# Geocoding: Bellefontaine, Logan County
# Geocoding: Portland, Me.
# Geocoding: Augusta, Me.
# Geocoding: Bay Saint Louis, Miss.
# Geocoding: Washington, D.C.
# Geocoding: Abbeville, S.C.
# Geocoding: Salt Lake City, Utah
# Geocoding: Augusta, Me.
# Geocoding: Trinidad, Colo.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: New York, N.Y.
# Geocoding: New York, N.Y.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Richmond, Va.
# Geocoding: Butte, Mont.
# Geocoding: Indianapolis, Ind.
# Geocoding: Leon, Iowa
# Geocoding: Olneyville, Providence
# Geocoding: Tucson, Pima County
# Geocoding: Hahnville, La.
# Geocoding: Barton, Vt.
# Geocoding: Anadarko, Oklahoma
# Geocoding: Washington, D.C.
# Geocoding: Atlanta, Ga.
# Geocoding: Washington, D.C.
# Geocoding: Holbrook, Navajo County [Ariz.
# Geocoding: Hartford, Ky.
# Geocoding: Washington, D.C.
# Geocoding: New Haven, Conn.
# Geocoding: Pensacola, Fla.
# Geocoding: Fairmont, W. Va.
# Geocoding: Cairo, Ill.
# Geocoding: Jamestown, Stutsman County
# Geocoding: Greeley, Colo.
# Geocoding: New Britain, Conn.
# Geocoding: Flagstaff, Ariz.
# Geocoding: Warner, Brown Co.
# Geocoding: Hawthorne, Nev.
# Geocoding: San Antonio, Tex.
# Geocoding: Willimantic, Conn.
# Geocoding: Santa Fe, N.M.
# Geocoding: Shoshone, Idaho
# Geocoding: Hendersonville, N.C.
# Geocoding: Washington, D.C.
# Geocoding: Ardmore, Okla.
# Geocoding: Keokuk, Iowa
# Geocoding: Cordele, Georgia
# Geocoding: Jamestown, Stutsman County
# Geocoding: Seattle, Wash.
# Geocoding: Boone, Watauga County
# Geocoding: Cordele, Georgia
# Geocoding: Wenatchee, Wash.
# Geocoding: Lakeland, Fla.
# Geocoding: Ironton, Iron County
# Geocoding: Marion, Ky.
# Geocoding: Vinita, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Indian Territory [Okla.
# Geocoding: Columbia, Ky.
# Geocoding: Socorro, N.M.
# Geocoding: The Dalles, Or.
# Geocoding: Okolona, Miss.
# Geocoding: Ardmore, Okla.
# Geocoding: Boone, Watauga County
# Geocoding: Washington, D.C.
# Geocoding: Key West, Fla.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Bisbee, Ariz.
# Geocoding: Mineral Park, A.T. [Ariz.
# Retrying after 3 seconds...
# Geocoding: Mineral Park, A.T. [Ariz.
# Retrying after 3 seconds...
# Geocoding: Mineral Park, A.T. [Ariz.
# Geocoding: Guildhall, Vt.
# Geocoding: Meade, Kan.
# Geocoding: Keokuk, Iowa
# Geocoding: Keokuk, Iowa
# Geocoding: Flagstaff, Ariz.
# Geocoding: Washburn, McLean County
# Geocoding: Elizabeth City, N.C.
# Geocoding: Vinita, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Indian Territory [Okla.
# Geocoding: Cairo, Ill.
# Geocoding: Kenna, Roosevelt County
# Geocoding: Socorro, N.M.
# Geocoding: Phoenix, Ariz.
# Geocoding: Vinita, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Indian Territory [Okla.
# Geocoding: Astoria, Oregon
# Geocoding: Mountain Home, Idaho
# Geocoding: Barre, Vt.
# Geocoding: Bemidji, Minn.
# Geocoding: Bemidji, Minn.
# Geocoding: Monroe, N.C.
# Geocoding: Phoenix, Ariz.
# Geocoding: Washington, D.C.
# Geocoding: Ocala, Fla.
# Geocoding: Washington, D.C.
# Geocoding: Chanute, Kan.
# Geocoding: Valdez, Alaska
# Geocoding: Perth Amboy, N.J.
# Geocoding: Bluefield, W. Va.
# Geocoding: Madison, S.D.
# Geocoding: Madison, S.D.
# Geocoding: Washington, D.C.
# Geocoding: Stillwater, Minn.
# Geocoding: Nezperce, Idaho
# Geocoding: Birmingham, Ala.
# Geocoding: Washington, D.C.
# Geocoding: Elbert, Elbert County
# Geocoding: Gardnerville, Nev.
# Geocoding: Brownsville, Tex.
# Geocoding: Olneyville, Providence
# Geocoding: El Centro, Calif.
# Geocoding: Waterbury, Conn.
# Geocoding: Juneau, Alaska
# Geocoding: Juneau, Alaska
# Geocoding: Belington, W. Va.
# Geocoding: Clarksburg, W. Va.
# Geocoding: Juneau, Alaska
# Geocoding: Laramie, Wyo.
# Geocoding: Leesburg, Ga.
# Geocoding: Batesville, Independence Co.
# Geocoding: Grand Rapids, Itasca County
# Geocoding: Liberal, Kan.
# Geocoding: Perrysburg, Wood Co.
# Geocoding: Stanford, Ky.
# Geocoding: Stanford, Ky.
# Geocoding: Walla Walla, Wash.
# Geocoding: Macon, Miss.
# Geocoding: Washington, D.C.
# Geocoding: Sacramento, Calif.
# Geocoding: Washington, D.C.
# Geocoding: Houston, Tex.
# Geocoding: Edgefield, S.C.
# Geocoding: Savannah, Ga.
# Geocoding: Mineral Point, Wis.
# Geocoding: Washington, D.C.
# Geocoding: Portland, Me.
# Geocoding: Portland, Me.
# Geocoding: New Haven, Conn.
# Geocoding: Washington, D.C.
# Geocoding: Providence, R.I.
# Geocoding: Washington, D.C.
# Geocoding: Coolidge, Ariz.
# Geocoding: Dillon, Mont.
# Geocoding: Washington, D.C.
# Geocoding: New York, N.Y.
# Geocoding: Vinita, Ind. Ter. [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Ind. Ter. [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Ind. Ter. [Okla.
# Geocoding: Indianapolis, Ind.
# Geocoding: Starkville, Miss.
# Geocoding: Grand Junction, Colo.
# Geocoding: Roanoke Rapids, N.C.
# Geocoding: Morris, Minn.
# Geocoding: Indianapolis, Ind.
# Geocoding: Indianapolis, Ind.
# Geocoding: Nome, Alaska
# Geocoding: Pine Bluff, Ark.
# Geocoding: Waterbury, Conn.
# Geocoding: Los Angeles, Calif.
# Geocoding: San Francisco, Calif.
# Geocoding: Phoenix, Ariz.
# Geocoding: Salt Lake City, Utah
# Geocoding: Lakeland, Fla.
# Geocoding: Memphis, Tenn.
# Geocoding: Hopkinsville, Ky.
# Geocoding: Vinita, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Indian Territory [Okla.
# Geocoding: Minneapolis, Minn.
# Geocoding: Heppner, Morrow County
# Geocoding: Cincinnati, Ohio
# Geocoding: Columbus, Miss.
# Geocoding: Tacoma, Wash.
# Geocoding: Washington, D.C.
# Geocoding: Shreveport, La.
# Geocoding: Hopkinsville, Ky.
# Geocoding: Honolulu, Hawaiian Islands
# Geocoding: Ocala, Fla.
# Geocoding: Salem, Oregon
# Geocoding: Ellisville, Miss.
# Geocoding: Anderson Court House, S.C.
# Retrying after 3 seconds...
# Geocoding: Anderson Court House, S.C.
# Retrying after 3 seconds...
# Geocoding: Anderson Court House, S.C.
# Geocoding: Anderson Court House, S.C.
# Retrying after 3 seconds...
# Geocoding: Anderson Court House, S.C.
# Retrying after 3 seconds...
# Geocoding: Anderson Court House, S.C.
# Geocoding: Skagway, Alaska
# Geocoding: Skagway, Alaska
# Geocoding: Washington, D.C.
# Geocoding: Valdez, Alaska
# Geocoding: Elk Point, Union County
# Geocoding: Washington, D.C.
# Geocoding: Madison, S.D.
# Geocoding: Washington, D.C.
# Geocoding: Stillwater, Minn.
# Geocoding: New Britain, Conn.
# Geocoding: Indianapolis, Ind.
# Geocoding: Indianapolis, Ind.
# Geocoding: Nogales, Ariz.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Mnateo, i.e. Manteo
# Retrying after 3 seconds...
# Geocoding: Mnateo, i.e. Manteo
# Retrying after 3 seconds...
# Geocoding: Mnateo, i.e. Manteo
# Geocoding: Nome, Alaska
# Geocoding: Nome, Alaska
# Geocoding: Lovelock, Nev.
# Geocoding: White Bluffs, Wash.
# Geocoding: Atlanta, Ga.
# Geocoding: Little Rock, Ark.
# Geocoding: Seward, Alaska
# Geocoding: Washington, D.C.
# Geocoding: Laramie, Wyo.
# Geocoding: San Antonio, Tex.
# Geocoding: Browning, Mont.
# Geocoding: Cordele, Georgia
# Geocoding: Batesville, Ark.
# Geocoding: Bennington, Vt.
# Geocoding: Ardmore, Okla.
# Geocoding: Douglas, Ariz.
# Geocoding: Seward, Alaska
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Retrying after 3 seconds...
# Geocoding: Christiansted, St. Croix [V.I.
# Geocoding: Seward, Alaska
# Geocoding: Rathdrum, Idaho
# Geocoding: Pierre, S.D.
# Geocoding: Pierre, S.D.
# Geocoding: Indiana, Pa.
# Geocoding: Wildwood, N.J.
# Geocoding: Denison, Iowa
# Geocoding: Pierre, S.D.
# Geocoding: Butte, Mont.
# Geocoding: Nome, Alaska
# Geocoding: Bismarck, N.D.
# Geocoding: Scooba, Miss.
# Geocoding: Washington, D.C.
# Geocoding: San Antonio, Tex.
# Geocoding: Pierre, S.D.
# Geocoding: Shepherdstown, Va. [W. Va.
# Geocoding: Great Salt Lake City, Utah
# Geocoding: New Haven, Conn.
# Geocoding: Lincoln, Neb.
# Geocoding: Perth Amboy, N.J.
# Geocoding: Ely, Minn.
# Geocoding: Bloomsburg, Pa.
# Geocoding: Phoenix, Ariz.
# Geocoding: Washington, D.C.
# Geocoding: Indianapolis, Ind.
# Geocoding: Douglas, Converse County
# Geocoding: Washington, D.C.
# Geocoding: Nome, Alaska
# Geocoding: Seattle, Wash. Terr. [Wash.
# Geocoding: Washington, D.C.
# Geocoding: Flagstaff, Ariz.
# Geocoding: New Haven, Conn.
# Geocoding: South Bend, Ind.
# Geocoding: Anaconda, Mont.
# Geocoding: Salt Lake City, Utah
# Geocoding: New Haven, Conn.
# Geocoding: Minneapolis, Minn.
# Geocoding: The Dalles, Or.
# Geocoding: The Dalles, Or.
# Geocoding: Worthington, Minn.
# Geocoding: The Dalles, Or.
# Geocoding: Washington, D.C.
# Geocoding: Williston, Williams County
# Geocoding: Boone, Watauga County
# Geocoding: Brownsville, Tex.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Rockville, Md.
# Geocoding: Beatrice, Neb.
# Geocoding: Washington, D.C.
# Geocoding: New York, N.Y.
# Geocoding: Ottawa, Ill.
# Geocoding: Dodge City, Kan.
# Geocoding: Spokane, Wash.
# Geocoding: Spokane, Wash.
# Geocoding: Washington, D.C.
# Geocoding: Minneapolis, Minn.
# Geocoding: Hartford, Ky.
# Geocoding: Langdon, N.D.
# Geocoding: Langdon, N.D.
# Geocoding: Langdon, N.D.
# Geocoding: Ironton, Iron County
# Geocoding: Challis, Idaho
# Geocoding: Tucson, Pima County
# Geocoding: Snow Hill, Md.
# Geocoding: Topeka, Kansas
# Geocoding: Phoenix, Ariz.
# Geocoding: Honolulu, Oahu
# Geocoding: Flagstaff, Ariz.
# Geocoding: Flagstaff, Ariz.
# Geocoding: Lewiston, Idaho
# Geocoding: Chickasha, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Chickasha, Indian Territory [Okla.
# Retrying after 3 seconds...
# Geocoding: Chickasha, Indian Territory [Okla.
# Geocoding: Rich Hill, Mo.
# Geocoding: Chicago, Ill.
# Geocoding: Manning, Clarendon County
# Geocoding: Waterbury, Connecticut
# Geocoding: Paducah, Ky.
# Geocoding: Winston, N.C.
# Geocoding: Ardmore, Okla.
# Geocoding: Mathews C.H., Court House
# Retrying after 3 seconds...
# Geocoding: Mathews C.H., Court House
# Retrying after 3 seconds...
# Geocoding: Mathews C.H., Court House
# Geocoding: Cloverport, Ky.
# Geocoding: New York, N.Y.
# Geocoding: Rising Sun, Md.
# Geocoding: Marion, Ohio
# Geocoding: Great Salt Lake City, Utah
# Geocoding: Willmar, Minn.
# Geocoding: Bennington, Vt.
# Geocoding: Seattle, Wash.
# Geocoding: Rising Sun, Md.
# Geocoding: Warren, Marshall County
# Geocoding: Bemidji, Minn.
# Geocoding: Bemidji, Minn.
# Geocoding: WaKeeney, Kan.
# Geocoding: Marshalltown, Iowa
# Geocoding: St. Johns, Apache Co.
# Geocoding: Phoenix, Ariz.
# Geocoding: Meridian, Idaho
# Geocoding: Santa Fe, N.M.
# Geocoding: Bamberg, S.C.
# Geocoding: Roanoke Rapids, N.C.
# Geocoding: Tabor City, N.C.
# Geocoding: Key West, Fla.
# Geocoding: Washington, D.C.
# Geocoding: Detroit, Mich.
# Geocoding: Detroit, Mich.
# Geocoding: Portland, Me.
# Geocoding: Fargo, N.D.
# Geocoding: Winslow, Ariz.
# Geocoding: Washington, D.C.
# Geocoding: Indianapolis, Ind.
# Geocoding: Edgerton, Wis.
# Geocoding: Bismarck, N.D.
# Geocoding: Wabeno, Wis.
# Geocoding: Washington, D.C.
# Geocoding: Libby, Mont.
# Geocoding: Birmingham, Ala.
# Geocoding: Jacksonville, Fla.
# Geocoding: Jacksonville, Fla.
# Geocoding: Jacksonville, Fla.
# Geocoding: Nome, Alaska
# Geocoding: Washington, D.C.
# Geocoding: Nome, Alaska
# Geocoding: Chicago, Ill.
# Geocoding: Oskaloosa, Mahaska County
# Geocoding: Nome, Alaska
# Geocoding: Waterbury, Conn.
# Geocoding: Tacoma, Wash.
# Geocoding: Eagle River, Vilas County
# Geocoding: Washington, D.C.
# Geocoding: River Falls, Pierce County
# Geocoding: Augusta, Me.
# Geocoding: Nicodemus, Kan.
# Geocoding: Montgomery, Ala.
# Geocoding: Providence, R.I.
# Geocoding: Woodstown, Salem Co.
# Geocoding: Harlem, Mont.
# Geocoding: New Haven, Conn.
# Geocoding: San Antonio, Tex.
# Geocoding: Minneapolis, Minn.
# Geocoding: Washington, D.C.
# Geocoding: Topeka, Kansas
# Geocoding: Washington, D.C.
# Geocoding: Roanoke Rapids, N.C.
# Geocoding: Mount Clemens, Mich.
# Geocoding: Nome, Alaska
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Pensacola, Fla.
# Geocoding: Covington, La.
# Geocoding: Washington, D.C.
# Geocoding: Indianapolis, Ind.
# Geocoding: Tucson, Ariz
# Geocoding: New York, N.Y.
# Geocoding: New York, N.Y.
# Geocoding: Baltimore, Md.
# Geocoding: Topeka, Kansas
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Retrying after 3 seconds...
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Retrying after 3 seconds...
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Geocoding: Washington, D.C.
# Geocoding: Abbeville, S.C.
# Geocoding: Washington, D.C.
# Geocoding: Freehold, N.J.
# Geocoding: Mineral Point, Wis.
# Geocoding: Mineral Point, Wis.
# Geocoding: Sacramento, Calif.
# Geocoding: Washington, D.C.
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Retrying after 3 seconds...
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Retrying after 3 seconds...
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Geocoding: Wichita, Kan.
# Geocoding: Kansas City, Mo.
# Geocoding: Tucson, Pima County
# Geocoding: Los Angeles, Calif.
# Geocoding: El Paso, Tex.
# Geocoding: South Londonderry, Vt.
# Geocoding: Watertown, Wis.
# Geocoding: New York, N.Y.
# Geocoding: Cresco, Howard County
# Geocoding: Harrison, Nebraska
# Geocoding: Birmingham, Ala.
# Geocoding: Birmingham, Ala.
# Geocoding: Worcester, Mass.
# Geocoding: New York, N.Y.
# Geocoding: Springfield, Mass.
# Geocoding: New York, N.Y.
# Geocoding: Great Salt Lake City, Utah
# Geocoding: St. Paul, Minn.
# Geocoding: Indianapolis, Ind.
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Retrying after 3 seconds...
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Retrying after 3 seconds...
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Geocoding: Tucson, Ariz
# Geocoding: Salisbury, Litchfield Co.
# Retrying after 3 seconds...
# Geocoding: Salisbury, Litchfield Co.
# Retrying after 3 seconds...
# Geocoding: Salisbury, Litchfield Co.
# Geocoding: New York, N.Y.
# Geocoding: Kansas City, Mo.
# Geocoding: Seattle, Wash. Terr. [Wash.
# Geocoding: Yorkville, S.C.
# Geocoding: Springfield, Mass.
# Geocoding: Chase, Mich.
# Geocoding: Detroit, Mich.
# Geocoding: Chapel Hill, N.C.
# Geocoding: Pawtucket, R.I.
# Geocoding: Montgomery, Ala.
# Geocoding: Richmond, Va.
# Geocoding: San Antonio, Tex.
# Geocoding: Lebanon, Linn County
# Geocoding: Carson City, Nev.
# Geocoding: Washington, D.C.
# Geocoding: Milford, Del.
# Geocoding: Richmond, Madison County
# Geocoding: Hot Springs, S.D.
# Geocoding: High Point, N.C.
# Geocoding: Grand Marais, Minn.
# Geocoding: Topeka, Kansas
# Geocoding: Ogden City, Utah
# Geocoding: Raleigh, N.C.
# Geocoding: Edgerton, Wis.
# Geocoding: Birmingham, Ala.
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Retrying after 3 seconds...
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Retrying after 3 seconds...
# Geocoding: Grand Rapids, i.e. Wisconsin Rapids
# Geocoding: Tonopah, Nev.
# Geocoding: Jackson, Amador County
# Geocoding: Hopkinsville, Ky.
# Geocoding: Chicago, Ill.
# Geocoding: Salmon City, Idaho
# Geocoding: Phoenix, Ariz.
# Geocoding: Phoenix, Ariz.
# Geocoding: Shoshone, Idaho
# Geocoding: Detroit, Mich
# Geocoding: Birmingham, Ala.
# Geocoding: Pine Bluff, Ark.
# Geocoding: Rawlins, Wyo.
# Geocoding: Dawson, Ga.
# Geocoding: Kingman, Ariz.
# Geocoding: Carson City, Nev.
# Geocoding: Exira, Iowa
# Geocoding: Exira, Iowa
# Geocoding: Tonopah, Nev.
# Geocoding: Richmond, Va.
# Geocoding: Rathdrum, Idaho
# Geocoding: Paris, Ky.
# Geocoding: Hopkinsville, Ky.
# Geocoding: Flagstaff, Ariz.
# Geocoding: Abbeville, Vermilion Parish
# Geocoding: Barre, Vt.
# Geocoding: Maysville, Ky.
# Geocoding: Maysville, Ky.
# Geocoding: Carson City, Nev.
# Geocoding: Tonopah, Nev.
# Geocoding: Red Cloud, Webster Co.
# Geocoding: Mitchell, Dakota [S.D.
# Geocoding: Sisseton, Roberts County
# Geocoding: Holbrook, Ariz.
# Geocoding: Topeka, Kan.
# Geocoding: Lakeland, Fla.
# Geocoding: Pendleton, OR
# Geocoding: Marion, Ohio
# Geocoding: Hopkinsville, Ky.
# Geocoding: Langdon, N.D.
# Geocoding: Las Vegas, N.M.
# Geocoding: Donaldsonville, La.
# Geocoding: Omaha, Neb.
# Geocoding: Astoria, Oregon
# Geocoding: Guildhall, Vt.
# Geocoding: Guildhall, Vt.
# Geocoding: San Francisco, Calif.
# Geocoding: Meade, Kan.
# Geocoding: San Francisco, Calif.
# Geocoding: Great Bend, Kan.
# Geocoding: Jackson, Amador County
# Geocoding: Minneapolis, Minn.
# Geocoding: Hopkinsville, Ky.
# Geocoding: Leesville, La.
# Geocoding: Jamestown, Stutsman County
# Geocoding: Washington, D.C.
# Geocoding: Amarillo, Tex.
# Geocoding: New York, N.Y.
# Geocoding: Vinita, Ind. Ter. [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Ind. Ter. [Okla.
# Retrying after 3 seconds...
# Geocoding: Vinita, Ind. Ter. [Okla.
# Geocoding: Cedar City, Utah
# Geocoding: Vinita, Craig County
# Geocoding: Challis, Idaho
# Geocoding: Challis, Idaho
# Geocoding: Earlington, Ky.
# Geocoding: Tacoma, Wash.
# Geocoding: Walla Walla, Wash.
# Geocoding: Walla Walla, Wash.
# Geocoding: Walla Walla, Wash.
# Geocoding: Pendleton, OR
# Geocoding: Perrysburg, Wood Co.
# Geocoding: Ardmore, Okla.
# Geocoding: Minot, Ward County
# Geocoding: Fairmont, W. Va.
# Geocoding: Pembina, Dakota [N.D.
# Geocoding: Ekalaka, Mont.
# Geocoding: Washington, D.C.
# Geocoding: Washington, D.C.
# Geocoding: Kingstree, S.C.
# Geocoding: Grants Pass, Or.
# Geocoding: Santa Fe, N.M.
# Geocoding: Mineral Point, Wis.
# Geocoding: Durham, N.C.
# Geocoding: Seattle, Wash.
# Geocoding: Pembina, Dakota [N.D.
# Geocoding: Jamestown, Stutsman County
# Geocoding: Spokane, Wash.
# Geocoding: Princeton, Minn.
# Geocoding: Princeton, Minn.
# Geocoding: Spokane, Wash.
# Geocoding: St. Paul, Minn.
# Geocoding: Barton, Vt.
# Geocoding: Bemidji, Minn.
# Geocoding: Oakes, N.D.
# Geocoding: Rising Sun, Md.
# Geocoding: Salt Lake City, Utah
# Geocoding: Marshall, Saline County
# Geocoding: Marshall, Saline County
# Geocoding: Sumter, S.C.
# Geocoding: Monroe, N.C.
# Geocoding: The Dalles, Or.
# Geocoding: Ardmore, Okla.
# Geocoding: Juneau, Alaska
# Geocoding: Mineral Park, A.T. [Ariz.
# Retrying after 3 seconds...
# Geocoding: Mineral Park, A.T. [Ariz.
# Retrying after 3 seconds...
# Geocoding: Mineral Park, A.T. [Ariz.
# Geocoding: Paw Paw, Mich.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 53
#      50 start_time = time.time()
#      52 # Apply the function to the DataFrame
# ---> 53 data['reclat'], data['reclong'] = zip(*data.apply(extract_coordinates, axis=1))
#      55 # Check for NaN values
#      56 print("NaN values after geocoding:", data[['reclat', 'reclong']].isnull().sum())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:10347, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10333 from pandas.core.apply import frame_apply
#   10335 op = frame_apply(
#   10336     self,
#   10337     func=func,
#    (...)
#   10345     kwargs=kwargs,
#   10346 )
# > 10347 return op.apply().__finalize__(self, method="apply")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[17], line 46, in extract_coordinates(row)
#      43     return None, None
#      45 city_state = row['City'] + ', ' + row['State']
# ---> 46 latitude, longitude = geocode_city_state(city_state)
#      47 return latitude, longitude
#
# Cell In[17], line 19, in geocode_city_state(city_state, max_retries)
#      17 print("Geocoding:", city_state)
#      18 url = f"https://nominatim.openstreetmap.org/search?format=json&q={city_state}"
# ---> 19 response = requests.get(url)
#      20 if response.status_code == 200:
#      21     data = response.json()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     464 try:
#     465     # Trigger any extra validation we need to do.
#     466     try:
# --> 467         self._validate_conn(conn)
#     468     except (SocketTimeout, BaseSSLError) as e:
#     469         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:1096, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 # Force connect early to allow us to validate the connection.
#    1095 if conn.is_closed:
# -> 1096     conn.connect()
#    1098 if not conn.is_verified:
#    1099     warnings.warn(
#    1100         (
#    1101             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1106         InsecureRequestWarning,
#    1107     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:782, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     779     if is_ipaddress(normalized):
#     780         server_hostname = normalized
# --> 782 ssl_sock = ssl_wrap_socket(
#     783     sock=sock,
#     784     keyfile=key_file,
#     785     certfile=cert_file,
#     786     key_password=key_password,
#     787     ca_certs=ca_certs,
#     788     ca_cert_dir=ca_cert_dir,
#     789     ca_cert_data=ca_cert_data,
#     790     server_hostname=server_hostname,
#     791     ssl_context=context,
#     792     tls_in_tls=tls_in_tls,
#     793 )
#     795 try:
#     796     if assert_fingerprint:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:470, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     467 except NotImplementedError:  # Defensive: in CI, we always have set_alpn_protocols
#     468     pass
# --> 470 ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls, server_hostname)
#     471 return ssl_sock
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/util/ssl_.py:514, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     511     SSLTransport._validate_ssl_context_for_tls_in_tls(ssl_context)
#     512     return SSLTransport(sock, ssl_context, server_hostname)
# --> 514 return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:455, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     449 def wrap_socket(self, sock, server_side=False,
#     450                 do_handshake_on_connect=True,
#     451                 suppress_ragged_eofs=True,
#     452                 server_hostname=None, session=None):
#     453     # SSLSocket class handles server_hostname encoding before it calls
#     454     # ctx._wrap_socket()
# --> 455     return self.sslsocket_class._create(
#     456         sock=sock,
#     457         server_side=server_side,
#     458         do_handshake_on_connect=do_handshake_on_connect,
#     459         suppress_ragged_eofs=suppress_ragged_eofs,
#     460         server_hostname=server_hostname,
#     461         context=self,
#     462         session=session
#     463     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1046, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1043         if timeout == 0.0:
#    1044             # non-blocking
#    1045             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1046         self.do_handshake()
#    1047 except (OSError, ValueError):
#    1048     self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/ssl.py:1321, in SSLSocket.do_handshake(self, block)
#    1319     if timeout == 0.0 and block:
#    1320         self.settimeout(None)
# -> 1321     self._sslobj.do_handshake()
#    1322 finally:
#    1323     self.settimeout(timeout)
#
# KeyboardInterrupt:
