# %%
import requests

def generate_pdf_link(lccn, date, sequence):
    # Construct the base URL for the PDF service
    base_url = "https://tile.loc.gov/storage-services/service/ndnp"
    
    # Extract the batch and page numbers from the date and sequence
    batch = date.replace("-", "") + "01"
    page = str(sequence).zfill(8)  # Convert sequence to a string and then apply zfill
    
    # Construct the PDF URL
    pdf_url = f"{base_url}/{lccn}/{batch}/{page}.pdf"
    
    return pdf_url

def search_meteorite_mentions():
    # Define the base URL for the Chronicling America API
    base_url = "https://chroniclingamerica.loc.gov"

    # Construct the API endpoint URL for searching pages with the word "meteorite"
    endpoint = "/search/pages/results/"
    url = f"{base_url}{endpoint}"

    # Define the parameters for the search query
    params = {
        "andtext": "meteorite",
        "format": "json"
    }

    # Make the GET request to the API
    response = requests.get(url, params=params)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the JSON response
        data = response.json()

        # Extract relevant information from the response
        for item in data['items']:
            # Extracting publication details
            city = item['place_of_publication'][0].split(",")[0] if 'place_of_publication' in item else 'Unknown'
            state = item['state'][0] if 'state' in item else 'Unknown'
            year = item['date'][:4] if 'date' in item else 'Unknown'
            
            # Constructing the URL of the page
            page_id = item['id'].split('/')[-1]  # Extract the page ID from the URL
            page_url = f"{base_url}/lccn/{item['lccn']}/{item['date']}/{item['sequence']}"
            
            # Generate the PDF link
            pdf_link = generate_pdf_link(item['lccn'], item['date'], item['sequence'])
            
            # Print the publication details along with the PDF link
            print(f"City: {city}, State: {state}, Year: {year}")
            print(f"Page URL: {page_url}")
            print(f"PDF Link: {pdf_link}\n")
    else:
        print("Error occurred while fetching data")

# Call the function to search for mentions of "meteorite"
search_meteorite_mentions()
# Out:
# City: O, State: Nebraska, Year: 1912
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn99021999/19120804/22
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn99021999/1912080401/00000022.pdf
#
# City: W, State: District of Columbia, Year: 1951
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83045462/19511216/175
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83045462/1951121601/00000175.pdf
#
# City: W, State: District of Columbia, Year: 1952
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83045462/19520217/109
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83045462/1952021701/00000109.pdf
#
# City: S, State: Utah, Year: 1912
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83045396/19120811/33
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83045396/1912081101/00000033.pdf
#
# City: W, State: District of Columbia, Year: 1963
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83045462/19630418/62
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83045462/1963041801/00000062.pdf
#
# City: W, State: District of Columbia, Year: 1930
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83045462/19300223/95
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83045462/1930022301/00000095.pdf
#
# City: G, State: Montana, Year: 1951
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn86075096/19511201/11
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn86075096/1951120101/00000011.pdf
#
# City: W, State: District of Columbia, Year: 1959
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83045462/19590329/123
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83045462/1959032901/00000123.pdf
#
# City: W, State: District of Columbia, Year: 1961
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83045462/19610317/52
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83045462/1961031701/00000052.pdf
#
# City: W, State: Massachusetts, Year: 1900
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn86086481/19001104/13
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn86086481/1900110401/00000013.pdf
#
# City: R, State: Virginia, Year: 1922
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83045389/19220702/42
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83045389/1922070201/00000042.pdf
#
# City: W, State: District of Columbia, Year: 1929
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83045462/19290714/84
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83045462/1929071401/00000084.pdf
#
# City: H, State: Hawaii, Year: 1904
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn82015415/19040326/1
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn82015415/1904032601/00000001.pdf
#
# City: M, State: Alabama, Year: 1924
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn84020645/19240316/33
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn84020645/1924031601/00000033.pdf
#
# City: N, State: New York, Year: 1906
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83030214/19060121/18
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83030214/1906012101/00000018.pdf
#
# City: B, State: Alabama, Year: 1900
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn86072192/19001104/14
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn86072192/1900110401/00000014.pdf
#
# City: D, State: Michigan, Year: 1942
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn88063294/19420927/62
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn88063294/1942092701/00000062.pdf
#
# City: R, State: Montana, Year: 1934
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn84036286/19340425/7
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn84036286/1934042501/00000007.pdf
#
# City: C, State: Georgia, Year: 1921
# Page URL: https://chroniclingamerica.loc.gov/lccn/2022239691/19210510/6
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/2022239691/1921051001/00000006.pdf
#
# City: N, State: New York, Year: 1906
# Page URL: https://chroniclingamerica.loc.gov/lccn/sn83030214/19060422/21
# PDF Link: https://tile.loc.gov/storage-services/service/ndnp/sn83030214/1906042201/00000021.pdf
